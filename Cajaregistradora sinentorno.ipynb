# %%
import os
C=1 #Variable iniciadora del ciclo While, actua como almacenamiento de la decisión del usuario para agregar productos a la venta
precios=[2890, 14980, 2980, 4990, 11000, 1192, 25900, 4500, 8500, 1900, 7980, 2096, 4380, 1088, 680] #las listas son como variables que pueden almacenar diferentes datos y de diferente clases 
#Y estas listas tienen un orden que va desde 0 hasta la cantidad de datos -1 

class Count: #Al definir la clase Count se puede trasladar datos entre funciones usando Count.la clase de forma que los contadores mantienen sus valores y se pueden asignar a otras variables conforme avanza el programa
    contador=0 #Sumatoria de los valores de venta
    resultado=0 #Valor de venta
def calcularVenta():#def crea funciones, aquí nombramos "calcularVenta()" 
        cod=precios[x] #Pongo [x] pq es un valor que puede variar según nuestra necesidad  
        print("El costo por unidad es de: $",precios[x])
        cant=int(input("¿Cuantas unidades va a llevar?: "))
        Count.resultado=cod*cant
        Count.contador=Count.resultado+Count.contador
        return print("El valor total de su compra es de: $",Count.resultado);#"return" marca que ya terminamos la función y si le ponen instrucciones es capaz de ejecutarlas
while C!=2:
    os.system("cls")
    print("¡¡¡Bienvenido a Supermarket!!! (ɔ◔v◔)ɔ ♥ ")
    print("¡Tenemos los mejores precios del mercado!")
    print("Estos son los productos que tenemos para tu disposición")
    print("Si desea comprar Leche pon 10, si desea comprar un cartón de huevos 11, si desea comprar Pan pon 12, \n  si desea comprar Chocolate pon 13, si desea comprar Café pon 14, si desea comprar Arepas pon 15, \n si desea comprar Queso pon 16, si desea comprar Harina pon 17, si desea comprar Azúcar pon 18,\n si desea comprar Sal pon 19, si desea comprar Aceite pon 20, si desea comprar Mantequilla pon 21, \n si desea comprar Atún pon 22, si desea comprar Cebolla pon 23 y si desea comprar Tomate pon 24")
    K=int(input("Qué desea comprar?"))
    
    if K==10:
        x=0
        calcularVenta()
    if K==11:
        x=1
        calcularVenta()
    if K==12:
        x=2
        calcularVenta()
    if K==13:
        x=3
        calcularVenta()
    if K==14:
        x=4
        calcularVenta()
    if K==15:
        x=5
        calcularVenta()
    if K==16:
        x=6
        calcularVenta()
    if K==17:
        x=7
        calcularVenta()
    if K==18:
        x=8
        calcularVenta()
    if K==19:
        x=9
        calcularVenta()
    if K==20:
        x=10
        calcularVenta()
    if K==21:
        x=11
        calcularVenta()
    if K==22:
        x=12
        calcularVenta()
    if K==23:
        x=13
        calcularVenta()
    if K==24:
        x=14
        calcularVenta()
    archivo= open('Factura.txt', 'a')
    archivo.write('\n'+'Usted a comprado el producto: '+ str(K) +'con un precio total de: '+str(Count.resultado)+'\n')

    C=int(input("Si desea comprar algo más ponga 1 de lo contrario ponga 2"))
if C==2:
 print("El programa ha finalizado")
 print("Debe pagar: $",Count.contador)
 archivo.write('\n'+'Precio Total compra:$'+str(Count.contador)+'\n')
# Out:
# ¡¡¡Bienvenido a Supermarket!!! (ɔ◔v◔)ɔ ♥
# ¡Tenemos los mejores precios del mercado!
# Estos son los productos que tenemos para tu disposición
# Si desea comprar Leche pon 10, si desea comprar un cartón de huevos 11, si desea comprar Pan pon 12,
#   si desea comprar Chocolate pon 13, si desea comprar Café pon 14, si desea comprar Arepas pon 15,
#  si desea comprar Queso pon 16, si desea comprar Harina pon 17, si desea comprar Azúcar pon 18,
#  si desea comprar Sal pon 19, si desea comprar Aceite pon 20, si desea comprar Mantequilla pon 21,
#  si desea comprar Atún pon 22, si desea comprar Cebolla pon 23 y si desea comprar Tomate pon 24
# Qué desea comprar?10
# El costo por unidad es de: $ 2890
# ¿Cuantas unidades va a llevar?: 2
# El valor total de su compra es de: $ 5780
# Si desea comprar algo más ponga 1 de lo contrario ponga 21
# ¡¡¡Bienvenido a Supermarket!!! (ɔ◔v◔)ɔ ♥
# ¡Tenemos los mejores precios del mercado!
# Estos son los productos que tenemos para tu disposición
# ...
